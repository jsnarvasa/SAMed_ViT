# %%
import torch
import pickle
import numpy as np

# %%
# Replace 'filename.pkl' with the actual file path
file_path = '/home/narvjes/data/PASTIS24/pickle24x24/40548_0.pickle'

# Open the file in binary read mode
with open(file_path, 'rb') as file:
    tensor = pickle.load(file)

print('Loaded Tensor:', tensor)
# Out:
# Loaded Tensor: {'img': array([[[[ 1385,  1408,  1407, ...,  1606,  1577,  1704],
#          [ 1372,  1386,  1437, ...,  1661,  1714,  1850],
#          [ 1435,  1392,  1331, ...,  1740,  1839,  1937],
#          ...,
#          [ 1323,  1260,  1236, ...,  1720,  1697,  1751],
#          [ 1254,  1259,  1296, ...,  1826,  1706,  1715],
#          [ 1233,  1210,  1243, ...,  1806,  1676,  1859]],
#
#         [[ 1195,  1324,  1362, ...,  1448,  1451,  1452],
#          [ 1321,  1321,  1312, ...,  1476,  1567,  1633],
#          [ 1369,  1366,  1300, ...,  1504,  1647,  1732],
#          ...,
#          [ 1177,  1154,  1114, ...,  1613,  1602,  1605],
#          [ 1155,  1115,  1110, ...,  1731,  1734,  1626],
#          [ 1152,  1127,  1073, ...,  1756,  1704,  1762]],
#
#         [[ 1344,  1465,  1486, ...,  1643,  1692,  1754],
#          [ 1471,  1567,  1514, ...,  1687,  1773,  1920],
#          [ 1511,  1623,  1582, ...,  1770,  1907,  2041],
#          ...,
# ...

# %%
tensor.keys()
# Out:
# dict_keys(['img', 'labels', 'doy'])

# %%
print(f'1st channel: {np.unique(tensor["labels"][0])}')
print(f'2nd channel: {np.unique(tensor["labels"][1])}')
print(f'3rd channel: {np.unique(tensor["labels"][2])}')
# Out:
# 1st channel: [ 0  1  8 19]
# 2nd channel: [  0   8  16  17  18  19  23  24  29  48  83  86  90 136 189 224]
# 3rd channel: [  0   3  32 143]

# %%
tensor['labels']
# Out:
# array([[[ 19,  19,  19, ...,   0,   0,   0],
#         [ 19,  19,  19, ...,   0,   0,   0],
#         [ 19,   0,  19, ...,   0,   0,   0],
#         ...,
#         [  8,   8,   8, ...,   0,   1,   1],
#         [  8,   8,   8, ...,   1,   1,   1],
#         [  8,   8,   8, ...,   1,   1,   1]],
#
#        [[ 24,  24,  24, ...,   0,   0,   0],
#         [ 24,  24,  24, ...,   0,   0,   0],
#         [ 23,   0,  24, ...,   0,  86,  86],
#         ...,
#         [136, 136, 136, ...,   0,  90,  90],
#         [136, 136, 136, ...,  90,  90,  90],
#         [136, 136, 136, ...,  90,  90,  90]],
#
#        [[143, 143, 143, ...,   0,   0,   0],
#         [143, 143, 143, ...,   0,   0,   0],
#         [143,   0, 143, ...,   0,  32,  32],
#         ...,
#         [143, 143, 143, ...,   0,   3,   3],
#         [143, 143, 143, ...,   3,   3,   3],
#         [143, 143, 143, ...,   3,   3,   3]]], dtype=uint8)
